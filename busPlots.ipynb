# %%
import plotly.plotly as py
import pandas as pd

py.sign_in('orgiele', '0hLF1CVCaH5sEU0CG9Ah')

from plotly.graph_objs import *

mapbox_access_token = 'pk.eyJ1Ijoib3JnaWVsZSIsImEiOiJjajJ4azAyYnkwMHZ4MnFxbm41d3JocHlzIn0.GDMQKR_XxQIZtPX8dq6K4g'

nightBuses14 = pd.concat([pd.read_json('file:data/14-05/buses-night-filtered.json'),
                       pd.read_json('file:data/14-05/buses2-night-filtered.json')])

normalBuses14 = pd.concat([pd.read_json('file:data/14-05/buses-normal-filtered.json'),
                        pd.read_json('file:data/14-05/buses2-normal-filtered.json'),
                        pd.read_json('file:data/14-05/buses3-normal-filtered.json')])

zoneBuses14 = pd.concat([pd.read_json('file:data/14-05/buses-zone-filtered.json'),
                        pd.read_json('file:data/14-05/buses2-zone-filtered.json'),
                        pd.read_json('file:data/14-05/buses3-zone-filtered.json')])

zoneSupplementaryBuses14 = pd.concat([pd.read_json('file:data/14-05/buses2-zone-supplementary-filtered.json'),
                       pd.read_json('file:data/14-05/buses3-zone-supplementary-filtered.json')])

zonePeriodicBuses14 = pd.read_json('file:data/14-05/buses3-zone-periodic-filtered.json')

fastBuses14 = pd.concat([pd.read_json('file:data/14-05/buses-fast-filtered.json'),
                        pd.read_json('file:data/14-05/buses2-fast-filtered.json'),
                        pd.read_json('file:data/14-05/buses3-fast-filtered.json')])

fastPeriodicBuses14 = pd.concat([pd.read_json('file:data/14-05/buses2-fast-periodic-filtered.json'),
                        pd.read_json('file:data/14-05/buses3-fast-periodic-filtered.json')])

zoneBuses15 = pd.read_json('file:data/15-05/buses3-zone-filtered.json')

fastBuses15 = pd.read_json('file:data/15-05/buses3-fast-filtered.json')

fastPeriodicBuses15 = pd.read_json('file:data/15-05/buses3-fast-periodic-filtered.json')

expressBuses15 = pd.read_json('file:data/15-05/buses3-express-filtered.json')

normalBuses15 = pd.read_json('file:data/15-05/buses3-normal-filtered.json')

def plotBuses(df, colors, file, pitch, zoom):
    data = Data([
        Scattermapbox(
            lat=df['Lat'],
            lon=df['Lon'],
            mode='markers',
            hoverinfo='text',
            marker=Marker(
                size=3,
                opacity=0.7,
                color=colors,
                colorscale='Portland' 
                #Pre-defined color scales - 'pairs' | 'Greys' | 'Greens' | 'Bluered' | 'Hot' | 'Picnic' | 
                #'Portland' | 'Jet' | 'RdBu' | 'Blackbody' | 'Earth' | 'Electric' | 'YIOrRd' | 'YIGnBu' 
            ),
            text=df['Lines']
        )
    ])

    layout = Layout(
        autosize=True,
        hovermode='closest',
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=dict(
                lat=52.228626,
                lon=21.005654
            ),
            pitch=pitch,
            zoom=zoom
        ),
    )

    fig = dict(data=data, layout=layout)
    py.image.save_as(fig, filename=file)
    from IPython.display import Image
    return Image(file)

# %%
plotBuses(nightBuses14,[int(x[1:]) for x in nightBuses14['Lines']] ,'buses-night14-filtered.png', 0, 8.6)

# %%
plotBuses(zoneBuses14,zoneBuses14['Lines'] ,'buses-zone14-filtered.png', 0, 8.2)

# %%
plotBuses(normalBuses14,normalBuses14['Lines'] ,'buses-normal14-filtered.png', 0, 8.6)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-2-072c3eb6f885> in <module>()
# ----> 1 plotBuses(normalBuses14,normalBuses14['Lines'] ,'buses-normal14-filtered.png', 0, 8.6)
#
# <ipython-input-1-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# ...

# %%
plotBuses(zoneSupplementaryBuses14,zoneSupplementaryBuses14['Lines'] ,'buses-zone-supplementary-14-filtered.png', 0, 8.2)

# %%
plotBuses(zonePeriodicBuses14,zonePeriodicBuses14['Lines'] ,'buses-zone-periodic-14-filtered.png', 0, 8.2)

# %%
plotBuses(fastBuses14,fastBuses14['Lines'] ,'buses-fast-14-filtered.png', 0, 8.2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-3-b29d9db00c01> in <module>()
# ----> 1 plotBuses(fastBuses14,fastBuses14['Lines'] ,'buses-fast-14-filtered.png', 0, 8.2)
#
# <ipython-input-1-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in get(figure_or_data, format, width, height, scale)
# ...

# %%
plotBuses(fastPeriodicBuses14,fastPeriodicBuses14['Lines'] ,'buses-fast-periodic-14-filtered.png', 0, 8.2)

# %%
plotBuses(fastBuses15,fastBuses15['Lines'] ,'buses-fast-15-filtered.png', 0, 8.2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-4-d01129e3400f> in <module>()
# ----> 1 plotBuses(fastBuses15,fastBuses15['Lines'] ,'buses-fast-15-filtered.png', 0, 8.2)
#
# <ipython-input-1-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in get(figure_or_data, format, width, height, scale)
# ...

# %%
plotBuses(fastPeriodicBuses15,fastPeriodicBuses15['Lines'] ,'buses-fast-periodic-15-filtered.png', 0, 8.2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-5-2102cb38213c> in <module>()
# ----> 1 plotBuses(fastPeriodicBuses15,fastPeriodicBuses15['Lines'] ,'buses-fast-periodic-15-filtered.png', 0, 8.2)
#
# <ipython-input-1-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# ...

# %%
plotBuses(zoneBuses15,zoneBuses15['Lines'] ,'buses-zone-15-filtered.png', 0, 8.2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-2-4ee430ab0eec> in <module>()
# ----> 1 plotBuses(zoneBuses15,zoneBuses15['Lines'] ,'buses-zone-15-filtered.png', 0, 8.2)
#
# <ipython-input-1-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in get(figure_or_data, format, width, height, scale)
# ...

# %%
plotBuses(expressBuses15,expressBuses15['Lines'] ,'buses-express-15-filtered.png', 0, 8.2)

# %%
plotBuses(normalBuses15,normalBuses15['Lines'] ,'buses-normal-15-filtered.png', 0, 8.2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-14-245f970d5faa> in <module>()
# ----> 1 plotBuses(normalBuses15,normalBuses15['Lines'] ,'buses-normal-15-filtered.png', 0, 8.2)
#
# <ipython-input-8-b85c54173618> in plotBuses(df, colors, file, pitch, zoom)
#      76
#      77     fig = dict(data=data, layout=layout)
# ---> 78     py.image.save_as(fig, filename=file)
#      79     from IPython.display import Image
#      80     return Image(file)
#
# H:\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in save_as(cls, figure_or_data, filename, format, width, height, scale)
#     785             filename += '.' + format
#     786
# --> 787         img = cls.get(figure_or_data, format, width, height, scale)
#     788
#     789         f = open(filename, 'wb')
#
# ...
